# %% [markdown]
# 目標:
# 安裝Basemap, 並且可以使用它繪製地理資訊. 這個教程中，我們將涉及地理繪圖module: Basemap。Basemap是Matplotlib的擴展.
#
# 重點:
# Basemap 在地圖集上的擴展應用
#
# 作業:
# 更改 Projection 的設定繪製出地球儀圖形
#
# 當 "projection" 參數為“ortho"時，所得圖位地球儀截面
#
# 當 "projection" 參數為“Mill"時，所得平展位面
#
# 查看 resolution / 經緯度座標的繪圖精細度

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# %%
#1
#創建基本地圖
#當 projection 參數為 ortho 時，所得圖位地球儀截面

#set figure size
plt.figure(figsize=(5,5))

#set figure form
m = Basemap(projection="ortho", lat_0=40, lon_0=-105)

#set color, NASA 寶石藍輸出
m.bluemarble()

#秀圖
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#2
#設置 Lambert 保形底圖
# resolution = none 跳過邊界數據集的處理
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=45,lat_2=55,lat_0=50,lon_0=-107)

m.bluemarble()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#3
m = Basemap(projection="mill", llcrnrlat=-90, llcrnrlon=-180, 
            urcrnrlat=90, urcrnrlon=180)
m.drawcoastlines()
m.drawcountries(linewidth=2)
m.drawstates(color="b")
m.drawcounties(color="darkred")
plt.title("Basemap Tutorial")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ProjError                                 Traceback (most recent call last)
# <ipython-input-33-a4a5ff1f2697> in <module>
#       3             urcrnrlat=90, urcrnrlon=180)
#       4 m.drawcoastlines()
# ----> 5 m.drawcountries(linewidth=2)
#       6 m.drawstates(color="b")
#       7 m.drawcounties(color="darkred")
#
# ~/anaconda3/envs/basemap_env/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in drawcountries(self, linewidth, linestyle, color, antialiased, ax, zorder)
#    1894         # intersect map boundary polygon.
#    1895         if not hasattr(self,'cntrysegs'):
# -> 1896             self.cntrysegs, types = self._readboundarydata('countries')
#    1897         # get current axes instance (if none specified).
#    1898         ax = ax or self._check_ax()
#
# ~/anaconda3/envs/basemap_env/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in _readboundarydata(self, name, as_polygons)
#    1407                                     # transformation from lat/lon to
#    1408                                     # map projection coordinates.
# -> 1409                                     bx, by = self(blons, blats)
#    1410                                     if not as_polygons or len(bx) > 4:
#    1411                                         polygons.append(list(zip(bx,by)))
#
# ~/anaconda3/envs/basemap_env/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in __call__(self, x, y, inverse)
#    1186             except TypeError:
#    1187                 y = [_dg2rad*yy for yy in y]
# -> 1188         xout,yout = self.projtran(x,y,inverse=inverse)
#    1189         if self.celestial and inverse:
#    1190             try:
#
# ~/anaconda3/envs/basemap_env/lib/python3.7/site-packages/mpl_toolkits/basemap/proj.py in __call__(self, *args, **kw)
#     291             outxy = self._proj4(xy, inverse=inverse)
#     292         else:
# --> 293             outx,outy = self._proj4(x, y, inverse=inverse)
#     294         if inverse:
#     295             if self.projection in ['merc','mill','gall']:
#
# ~/anaconda3/envs/basemap_env/lib/python3.7/site-packages/pyproj/proj.py in __call__(self, longitude, latitude, inverse, errcheck, radians)
#     185             direction=direction,
#     186             errcheck=errcheck,
# --> 187             radians=radians,
#     188         )
#     189
#
# ~/anaconda3/envs/basemap_env/lib/python3.7/site-packages/pyproj/transformer.py in transform(self, xx, yy, zz, tt, radians, errcheck, direction)
#     493             direction=direction,
#     494             radians=radians,
# --> 495             errcheck=errcheck,
#     496         )
#     497         # if inputs were lists, tuples or floats, convert back.
#
# pyproj/_transformer.pyx in pyproj._transformer._Transformer._transform()
#
# ProjError: x, y, z, and time must be same size
